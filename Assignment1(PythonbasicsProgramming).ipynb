# %%
#Question 1
print("Hello Python")
# Out:
# Hello Python

# %%
#2)Write a Python program to do arithmetical operations addition and division.?
a= 2 
b= 3
add = a+b
div = a/b
print("Addition of a and b =",add)
print("Division of a and b", div)
# Out:
# Addition of a and b = 5
# Division of a and b 0.6666666666666666

# %%
#3)Write a Python program to find the area of a triangle?
h=int(input("enter the height of the triangle"))
b = int(input("enter the width of the triangle"))
area = (h*b)/2
print("Area of the triangle is", area)
# Out:
# enter the height of the triangle2
# enter the width of the triangle3
# Area of the triangle is 3.0

# %%
#4) Program to swap two variable 
a= int(input("enter the first number"))
b = int(input("enter the second number"))
print("before swapping", a , b)
(a,b)=(b,a)
print("after swapping", a, b)
# Out:
# enter the first number2
# enter the second number3
# before swapping 2 3
# after swapping 3 2

# %%
#5) Program to generate a random number 
import random
num_list = []
for i in range(1,100):
  num_list.append(i)
print("randomly selecting a number")
print(random.choice(num_list))
# Out:
# randomly selecting a number
# 37
