# %%
#Question 1:
dict= {}

# %% [markdown]
# #Question 2:
# 42

# %% [markdown]
# #Question 3:
# List are ordered while dictionary is unordered. The values inside the dictionary are accessed by the keys and the values inside the lists are accessed by the index positions

# %% [markdown]
# Question 4:
# The spam dictionary does not have the key named 'foo'. so it will show a key error

# %% [markdown]
# Question 5:
# There is no diference between the two expressions. it will give a True output

# %% [markdown]
# Question 6:
# 'cat' in spam will give you an output True while 'cat' in spam.values() gives you a False output. If cat is a value given to a key then the second expressions stands corrected. It will be True

# %% [markdown]
# Question 7:
# spam.setdefault('color','black')

# %% [markdown]
# Question 8:
# pprint module can be imported and the functions pprint() and pformat() can be sued to "pretty print" dictionary values
