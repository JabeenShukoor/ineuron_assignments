# %% [markdown]
# # ASSIGNMENT 1

# %% [markdown]
# Question 1
# values are :
#     'hello' -string
#     -87.8 - float
#     6 - interger
# expressions are:
#     / , + , - , *

# %% [markdown]
# Question 2
# difference bewteen a string and variable :
# String is a datatype in python. It is basically a sequence of letters.
# Variable is a place where you can store a value. Variable cannot start with a number.

# %% [markdown]
# Question 3
# Different data types in python are:
# Integer : This includes all the integer numbers
# Float: This includes all the decimal numbers
# String: It is basically a sequence of letters
# Boolean : this includes the True or False values

# %% [markdown]
# Question 4
# Expression in python can perform mathematical operations. It will have an assignemnt operator (=). some of the operators used in expressions are : + , -, * , / etc

# %% [markdown]
# Question 5
# An expression can compute and give us an output. It performs a mathemtical computation while a statement will not do any computation processes. For example spam=10 assigns the value 10 tothe variable spam. While a=spam+2 is an expression since it computes and give a  the value of 12

# %% [markdown]
# Question 6:
# value of bacon is 22. This is because the addition was not assigned to a variable and so the value of bacon will not change.

# %% [markdown]
# Question 7:
# 1) spamspamspam
# 2) spamspamspam
# Both gives the same output

# %% [markdown]
# Question 8 :
# Variables can only start with letters and not numbers. so the variable name eggs will be valid while 100 can be kept as a variable

# %% [markdown]
# Question 9:
# type() function can used to know the datatype of a value.

# %% [markdown]
# Question 10:
# Here 99 is an integer datatype. So adding the integer datatype with a string datatype will not give us an output. To fix the error we can typecast the integer value to a string datatype.
# Two methods:
# 1) 'I have eaten' + ' 99 ' + 'burritos.'
# 2) 'I have eaten ' + str(99) + ' burritos.'
