# %% [markdown]
# 1) An escape character is denoted by '\'. It is used to insert a character.

# %% [markdown]
# 2) \n stands for adding a new line while \t represents a tab

# %% [markdown]
# 3) \\ can be used to include backslach characters

# %% [markdown]
# 4) The string "Howl's Moving Castle" does not show an error because we have used double quotes for the string and the character inside the string is a single quote.

# %% [markdown]
# 6) 'e' ,
# 'Hello',
# 'Hello' ,
# 'lo, world!'

# %% [markdown]
# 7) 'HELLO' , TRUE ,

# %% [markdown]
# 8) ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.'],
#
# There-can-only-one.

# %% [markdown]
# 9) left justifying - str.ljust,
#
# right justifying  - str.rjust,
#
# centre - str.center

# %% [markdown]
# 10) The best way to remove whitespace would be to use the replace function.
