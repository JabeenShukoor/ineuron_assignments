# %% [markdown]
# Question 1:
# In python a list is created by using the square brackets [] . It can store any data type and is mutable

# %%
#Question 2:
spam=[2,4,6,8,10]
print(spam)
#changing the third value as hello
spam[2]='hello'
print(spam)
# Out:
# [2, 4, 6, 8, 10]
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# Question 3:
# output: [8]

# %% [markdown]
# Question 4:
# Output: [10]

# %% [markdown]
# Question 5:
# output :
# [2,4]

# %% [markdown]
# Question 6:
# output: 1

# %% [markdown]
# Question 7:
# the list changes to
# [3.14,'cat',11,'cat',True,99]

# %% [markdown]
# Question 8:
# the list changes to
# [3.14,11,'cat',True,99]

# %% [markdown]
# Question 9:
# List concatenation operators are :
# 1) + operator can be used
# 2) extend()
# 3) * operator can also be used
#
# list replication operators:
# 1) * operator

# %% [markdown]
# Question 10:
# the append() adds a new item to the end of the list. If you use insert(), we can provide the position at which the item is to be added in the list

# %% [markdown]
# Question 11:
# del operator can be used to remove items from list. pop is another method to delet values from a list

# %% [markdown]
# Question 12:
# the lists are very similar to strings in python because both of them is a collecton of characters/values which has a specific indexing. In list ech item has a specified index position and this is the case of strings as well. each character in a string has an index position and these characters/items can accessed using these indices

# %% [markdown]
# Question 13:
# Lists  can store any datatype and are mutable. Tuples are immutable and they store items in a key:value format. Lists are denoted by [] and tuples are denoted by ().

# %% [markdown]
# Question 14:

# %% [markdown]
# Question 15:
# You can typecast and convert a list to tuple and tuple to list
# list()
# tuple()

# %% [markdown]
# Question 16:
# variables that contain list values are not list themselves but they are just a reference to a list

# %% [markdown]
# Question 17:
# copy.copy()- uses copy() from copy module which does a shallow copy
# copy.deepcopy() - uses deepcopy() from the copy module and does a deep copy. the process occurs recursively
