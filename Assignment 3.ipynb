# %% [markdown]
# Question1:
# Functions can be resued anywhere we want. It improves the clarity of the code. Reducing redundancy

# %% [markdown]
# Question 2:
# When the fuction is called

# %% [markdown]
# Question 3:
# def <functionname>(arguments):
#     <fucntion body>

# %% [markdown]
# Question 4:
# Function call is used when we want to run the block of code inside the fucntion. While function is just a process of doing a work. There are user defined fucntions as well as built in fucntions in python

# %% [markdown]
# Question 5:
# there is only one global scope and many local scopes can be given inside afunction

# %% [markdown]
# Question 6:
# when the fucntion call returns the local scope variables do not fucntion any more

# %% [markdown]
# Question 7:
# the return value returns a value outside the userdefined function. It ends the execution of the fucntion. Yes return value can be given in an expression

# %% [markdown]
# Question 8 :
# None

# %% [markdown]
# Question 9 :
# Fucntion variables are local and can be accessed only inside the fucntion. If you want to access that variable global, you will have to declare it outside the fucntion

# %% [markdown]
# Question 10:
# It is the data type of the class NoneType object

# %% [markdown]
# Question 11:
# it imports the module called areallyourpetsnamederic

# %% [markdown]
# Question 12:
# import spam
# bacon()

# %% [markdown]
# Question 13:
# Error handling can be used which notifies the user what kind of an error has occured.

# %% [markdown]
# Question  14:
# try clause can be used to test the code for any errors while execpt clause helps to handle the error.
